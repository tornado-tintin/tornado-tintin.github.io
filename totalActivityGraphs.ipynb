# %%
import pandas as pd
mainnet = pd.read_json('daily-events.json')
matic = pd.read_json('daily-events-matic.json')
bsc = pd.read_json('daily-events-bsc.json')
arbitrum = pd.read_json('daily-events-arbitrum.json')
gnosis = pd.read_json('daily-events-gnosis.json')
avalanche = pd.read_json('daily-events-avalanche.json')

# %%
df = pd.concat([mainnet,matic,bsc,arbitrum,gnosis,avalanche],axis=1).fillna(method='ffill')

# %% [markdown]
# # level 1 (100$)

# %%
# %matplotlib notebook
df[['cdai-5000-D',
    'cdai-5000-W',
    'dai-100-D',
    'dai-100-W',
    'usdc-100-D',
    'usdc-100-W',
    'eth-0.1-D',
    'eth-0.1-W',
    'bnb-01-D',
    'bnb-01-W',
    'matic-100-D',
    'matic-100-W',
    'eth_arb-01-D',
    'eth_arb-01-W',
    'xdai-100-D',
    'xdai-100-W'
   ]].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>

# %% [markdown]
# excluding eth(main) bnb and matic

# %%
# %matplotlib notebook
df[['cdai-5000-D',
    'cdai-5000-W',
    'dai-100-D',
    'dai-100-W',
    'usdc-100-D',
    'usdc-100-W',
    'eth_arb-01-D',
    'eth_arb-01-W',
    'xdai-100-D',
    'xdai-100-W'
   ]].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>

# %% [markdown]
# # level 2 (1000$)

# %%
# %matplotlib notebook
df[['cdai-50000-D',
    'cdai-50000-W',
    'dai-1000-D',
    'dai-1000-W',
    'usdc-1000-D',
    'usdc-1000-W',
    'eth-1-D',
    'eth-1-W',
    'bnb-1-D',
    'bnb-1-W',
    'matic-1000-D',
    'matic-1000-W',
    'eth_arb-1-D',
    'eth_arb-1-W',
    'xdai-1000-D',
    'xdai-1000-W',
    'avax-10-D',
    'avax-10-W'
   ]].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>

# %% [markdown]
# excluding eth(mainnet) and bnb

# %%
# %matplotlib notebook
df[['cdai-50000-D',
    'cdai-50000-W',
    'dai-1000-D',
    'dai-1000-W',
    'usdc-1000-D',
    'usdc-1000-W',
    'matic-1000-D',
    'matic-1000-W',
    'eth_arb-1-D',
    'eth_arb-1-W',
    'xdai-1000-D',
    'xdai-1000-W',
    'avax-10-D',
    'avax-10-W'
   ]].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>

# %%
# %matplotlib notebook
df[['cdai-50000-D',
    'cdai-50000-W',
    'dai-1000-D',
    'dai-1000-W',
    'usdc-1000-D',
    'usdc-1000-W',
    'matic-1000-D',
    'matic-1000-W',
    'eth_arb-1-D',
    'eth_arb-1-W',
    'xdai-1000-D',
    'xdai-1000-W',
    'avax-10-D',
    'avax-10-W'
   ]].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>

# %% [markdown]
# # level 3 (10,000$)

# %%
df[[
    'eth-10-D',
    'eth-10-W',
    'dai-10000-D',
    'dai-10000-W',
    'cdai-500000-D',
    'cdai-500000-W',
    'wbtc-1-D',
    'wbtc-1-W',
    'bnb-10-D',
    'bnb-10-W',
    'matic-10000-D',
    'matic-10000-W',
    'eth_arb-10-D',
    'eth_arb-10-W',
    'xdai-10000-D',
    'xdai-10000-W',
    'avax-100-D',
    'avax-100-W'
]].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>

# %% [markdown]
# excluding eth(mainnet) and bnb

# %%
df[[
    'dai-10000-D',
    'dai-10000-W',
    'cdai-500000-D',
    'cdai-500000-W',
    'wbtc-1-D',
    'wbtc-1-W',
    'matic-10000-D',
    'matic-10000-W',
    'eth_arb-10-D',
    'eth_arb-10-W',
    'xdai-10000-D',
    'xdai-10000-W',
    'avax-100-D',
    'avax-100-W'
]].plot()
# Out:
# <img src="data:image/png;base64,..." width="956">
# <AxesSubplot:>

# %% [markdown]
# # level 4 (100,000$)

# %%
df[[
    'eth-100-D',
    'eth-100-W',
    'dai-100000-D',
    'dai-100000-W',
    'cdai-5000000-D',
    'cdai-5000000-W',
    'wbtc-10-D',
    'wbtc-10-W',
    'bnb-100-D',
    'bnb-100-W',
    'matic-100000-D',
    'matic-100000-W',
    'eth_arb-100-D',
    'eth_arb-100-W',
    'xdai-100000-D',
    'xdai-100000-W',
    'avax-500-D',
    'avax-500-W'
]].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>

# %% [markdown]
# excluding eth(mainnet) and bnb

# %%
df[[
    'dai-100000-D',
    'dai-100000-W',
    'cdai-5000000-D',
    'cdai-5000000-W',
    'wbtc-10-D',
    'wbtc-10-W',
    'matic-100000-D',
    'matic-100000-W',
    'eth_arb-100-D',
    'eth_arb-100-W',
    'xdai-100000-D',
    'xdai-100000-W',
    'avax-500-D',
    'avax-500-W'
]].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:>
